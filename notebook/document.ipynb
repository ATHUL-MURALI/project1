# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="hi i am athul murali",
    metadata = {"source": "sample.txt", "author":"athul", "pages":5, "date_created":"2024-06-10"}
)

# %%
doc
